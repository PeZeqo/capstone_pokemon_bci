# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cdata_1 = pd.read_csv('templates/sultan_checkerboard_1.csv', skiprows=0, header=1)

# %%
headers = cdata_1.columns.values.tolist()

# %%
headers
# Out:
# ['Timestamp',
#  'EEG.Counter',
#  'EEG.Interpolated',
#  'EEG.AF3',
#  'EEG.F7',
#  'EEG.F3',
#  'EEG.FC5',
#  'EEG.T7',
#  'EEG.P7',
#  'EEG.O1',
#  'EEG.O2',
#  'EEG.P8',
#  'EEG.T8',
#  'EEG.FC6',
#  'EEG.F4',
#  'EEG.F8',
#  'EEG.AF4',
#  'EEG.RawCq',
#  'EEG.Battery',
#  'MarkerIndex',
#  'MarkerType',
#  'MarkerValueInt',
#  'EEG.MarkerHardware',
#  'CQ.AF3',
#  'CQ.F7',
#  'CQ.F3',
#  'CQ.FC5',
#  'CQ.T7',
#  'CQ.P7',
#  'CQ.O1',
#  'CQ.O2',
#  'CQ.P8',
#  'CQ.T8',
#  'CQ.FC6',
#  'CQ.F4',
#  'CQ.F8',
#  'CQ.AF4',
#  'CQ.Overall']

# %%
cdata_1.plot(y='EEG.O1', x='Timestamp')

# %%
cdata_1.plot(y='EEG.O2', x='Timestamp')

# %%
cdata_2 = pd.read_csv('templates/sultan_checkerboard_2.csv', skiprows=0, header=1)
cdata_2.plot(y='EEG.O1', x='Timestamp')
cdata_2.plot(y='EEG.O2', x='Timestamp')

# %%
cdata_3 = pd.read_csv('templates/sultan_checkerboard_3.csv', skiprows=0, header=1)
cdata_3.plot(y='EEG.O1', x='Timestamp')
cdata_3.plot(y='EEG.O2', x='Timestamp')

# %%
cdata_4 = pd.read_csv('templates/sultan_checkerboard_4.csv', skiprows=0, header=1)
cdata_4.plot(y='EEG.O1', x='Timestamp')
cdata_4.plot(y='EEG.O2', x='Timestamp')

# %%
cdata_5 = pd.read_csv('templates/sultan_checkerboard_5.csv', skiprows=0, header=1)
cdata_5.plot(y='EEG.O1', x='Timestamp')
cdata_5.plot(y='EEG.O2', x='Timestamp')

# %%
cdata_6 = pd.read_csv('templates/sultan_checkerboard_6.csv', skiprows=0, header=1)
cdata_6.plot(y='EEG.O1', x='Timestamp')
cdata_6.plot(y='EEG.O2', x='Timestamp')

# %%
cdata_7 = pd.read_csv('templates/sultan_checkerboard_7.csv', skiprows=0, header=1)
cdata_7.plot(y='EEG.O1', x='Timestamp')
cdata_7.plot(y='EEG.O2', x='Timestamp')

# %%
cdata_8 = pd.read_csv('templates/sultan_checkerboard_8.csv', skiprows=0, header=1)
cdata_8.plot(y='EEG.O1', x='Timestamp')
cdata_8.plot(y='EEG.O2', x='Timestamp')
