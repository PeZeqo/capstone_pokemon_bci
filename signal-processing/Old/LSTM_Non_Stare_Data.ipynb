# %% [markdown]
# <h1> Imports

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt 
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFdr
from scipy.signal import butter, lfilter, filtfilt, freqz
from scipy import signal
import pywt

# %% [markdown]
# <h1> Fitlering Functions

# %%
def apply_butterband_filter(input_df):
    df = input_df.copy()
    for col in df.columns:
        df[col] = filter_df_col(df, col)
        
    return df

def filter_df_col(df, col):
    fs = 512.0
    lowcut = 12.0
    highcut = 25.0
    
    vals = df[col].values
    return butter_bandpass_filter(vals, lowcut, highcut, fs)

def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=3):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    data = data * 50    # amplify data
    y = filtfilt(b, a, data)
    return y

# %%
def wavelet_dwt(df):
    return pywt.dwt(df.values, 'db5')

def pca_and_inverse(df):
    pca = PCA(0.90).fit(df)
    components = pca.transform(df)
    return pca.inverse_transform(components)
    
def pca_feature_selection(df):
    pca = PCA(1).fit(df)
    return pca.transform(df)

# %%
record_export_folder = 'recordings'
# keep_cols = ['EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8'] # ['Timestamp', 'EEG.Counter', 'EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8']
keep_cols = ['P7', 'O1', 'O2', 'P8'] # ['EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8'] # ['Timestamp', 'EEG.Counter', 'EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8']

def load_df(file_name):
    file_path = os.path.join(record_export_folder, file_name)
    return pd.read_csv(file_path, skiprows=0, header=0)

def trim_cols(df):
    return df[keep_cols]

def filter_data(df):
#     df = apply_butterband_filter(df)
    return wavelet_dwt(df)

# %% [markdown]
# <h1> Data from 4 Sensors

# %%
df = trim_cols(load_df('checkerboard_recording_sultan_{}.csv'.format(1)))
approx, decomp = filter_data(df)
decomp = np.asarray(decomp)

# %%
subplot = 0
fig, axs = plt.subplots(4)
for col in df.columns:
    axs[subplot].plot(df[col].values)
    subplot += 1

# %% [markdown]
# <h1> Wavlet Decomposition

# %%
bands = approx.shape[1]
subplot = 0
axis = 0
fig, axs = plt.subplots(bands, 2)
for dataset in [approx, decomp]:
    for col in range(bands):
        axs[subplot, axis].plot(dataset[:,col])
        subplot += 1
    subplot = 0
    axis += 1

# %% [markdown]
# <h1> PCA Seperating Approx and Discrete

# %%
bands = approx.shape[1]
subplot = 0
axis = 0
pca_approx = pca_and_inverse(approx) 
pca_decomp = pca_and_inverse(decomp)
fig, axs = plt.subplots(bands, 2)
for dataset in [pca_approx, pca_decomp]:
    for col in range(bands):
        axs[subplot, axis].plot(dataset[:,col])
        subplot += 1
    subplot = 0
    axis += 1

# %% [markdown]
# <h1> PCA

# %%
subplot = 0
axis = 0
full = np.concatenate((approx, decomp), axis=1)
pca_full = pca_and_inverse(full)
bands = pca_full.shape[1]

# %%
fig, axs = plt.subplots(int(bands / 2), 2)
for col in range(bands):
    axs[subplot, axis].plot(pca_full[:,col])
    subplot += 1
    if subplot == int(bands / 2):
        subplot = 0
        axis += 1

# %% [markdown]
# <h1> Training Data

# %%
from sklearn.preprocessing import minmax_scale

# %%
seconds_to_check = 1
seconds_per_recording = 15
interval_range = int(128 * seconds_to_check)
data_points = int(seconds_per_recording / seconds_to_check)

def split_to_training_data(df):
    total_data = []
    for interval_start in range(0, interval_range * data_points, interval_range):
        temp_data = []
        for col in range(0, df.shape[1]):
            temp_data.append(df[interval_start:interval_start + interval_range, col])
        
        total_data.append(temp_data)
        
    return np.asarray(total_data)

def create_target_data(data, target):
    return np.asarray([target] * data.shape[0])

def scale_and_normalize(data):
#     print(data.shape)
    for col in range(data.shape[1]):
        data[:,col] = minmax_scale(data[:,col])
    return data
#     return minmax_scale(data)

# %%
targets = range(0, 8)
total_train_x = []
total_train_y = []
for target in targets:
    df = trim_cols(load_df('checkerboard_recording_sultan_{}.csv'.format(target)))
    approx, decomp = filter_data(df)
    pca_approx = pca_and_inverse(approx) 
    pca_decomp = pca_and_inverse(decomp)
    total_data = np.concatenate((pca_approx, pca_decomp), axis=1)
#     total_data = pca_approx
#     total_data = pca_decomp
    total_data = scale_and_normalize(total_data)
    train_x = split_to_training_data(total_data)
    train_y = create_target_data(train_x, target)
    if target == targets[0]:
        total_train_x = train_x
        total_train_y = train_y
    else:
        total_train_x = np.concatenate((total_train_x, train_x))
        total_train_y = np.concatenate((total_train_y, train_y))

# %%
total_train_x.shape
# Out:
# (120, 12, 128)

# %%
train_x, validation_x, train_y, validation_y = train_test_split(total_train_x, total_train_y, test_size = 0.25)

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, GRU, BatchNormalization, LayerNormalization, ActivityRegularization
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping

# %%
def create_model():
    model = Sequential()
    model.add(LSTM(32, input_shape=(train_x.shape[1:]), return_sequences=True))
    model.add(Dropout(0.5))
#     model.add(ActivityRegularization(l2=0.01))
#     model.add(BatchNormalization())

    model.add(LSTM(32, input_shape=(train_x.shape[1:]), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(ActivityRegularization(l2=0.002))
#     model.add(BatchNormalization())

    model.add(LSTM(32, input_shape=(train_x.shape[1:]), return_sequences=False))
    model.add(Dropout(0.5))
#     model.add(ActivityRegularization(l2=0.01))
#     model.add(BatchNormalization())

#     model.add(Dense(16))

    model.add(Dense(8, activation="softmax"))
    
    return model

# %%
EPOCHS = 200
BATCH_SIZE = 8
NAME= "models\BEST"

# %%
model = create_model()
    
opt = tf.keras.optimizers.Adam()

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt, metrics=['acc'])

callbacks = [
#     TensorBoard(f"logs\LSTM-{int(time.time())}"),
    ReduceLROnPlateau(patience=15, factor=0.8),
    EarlyStopping(patience=50),
#     ModelCheckpoint(filepath=NAME, monitor='val_loss', verbose=2, save_weights_only=True, save_best_only=True, mode='min')
]
    
history = model.fit(train_x,
                    train_y,
                    batch_size= BATCH_SIZE,
                    epochs = EPOCHS,
                    validation_data=(validation_x, validation_y), 
                    callbacks=callbacks)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 1s 95ms/step - loss: 2.1064 - acc: 0.1333 - val_loss: 2.1297 - val_acc: 0.1333
# Epoch 2/200
# 12/12 [==============================] - 0s 8ms/step - loss: 2.1112 - acc: 0.1111 - val_loss: 2.1312 - val_acc: 0.0667
# Epoch 3/200
# 12/12 [==============================] - 0s 10ms/step - loss: 2.0889 - acc: 0.1778 - val_loss: 2.1305 - val_acc: 0.0667
# Epoch 4/200
# 12/12 [==============================] - 0s 14ms/step - loss: 2.0413 - acc: 0.2333 - val_loss: 2.1536 - val_acc: 0.0667
# Epoch 5/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.0724 - acc: 0.1444 - val_loss: 2.1841 - val_acc: 0.0667
# Epoch 6/200
# 12/12 [==============================] - 0s 12ms/step - loss: 2.0693 - acc: 0.1667 - val_loss: 2.1418 - val_acc: 0.0667
# Epoch 7/200
# 12/12 [==============================] - 0s 9ms/step - loss: 2.0701 - acc: 0.1111 - val_loss: 2.1262 - val_acc: 0.0667
# Epoch 8/200
# 12/12 [==============================] - 0s 10ms/step - loss: 2.0412 - acc: 0.2111 - val_loss: 2.1033 - val_acc: 0.2000
# Epoch 9/200
# 12/12 [==============================] - 0s 9ms/step - loss: 2.0522 - acc: 0.2333 - val_loss: 2.0767 - val_acc: 0.0667
# Epoch 10/200
# 12/12 [==============================] - 0s 8ms/step - loss: 2.0254 - acc: 0.2667 - val_loss: 2.0593 - val_acc: 0.1667
# Epoch 11/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9037 - acc: 0.3000 - val_loss: 2.0039 - val_acc: 0.1667
# Epoch 12/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9233 - acc: 0.2111 - val_loss: 1.9654 - val_acc: 0.2333
# Epoch 13/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8535 - acc: 0.2556 - val_loss: 1.9687 - val_acc: 0.2000
# Epoch 14/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8835 - acc: 0.2556 - val_loss: 2.1240 - val_acc: 0.2333
# Epoch 15/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8864 - acc: 0.2000 - val_loss: 1.9947 - val_acc: 0.1333
# Epoch 16/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8612 - acc: 0.2333 - val_loss: 1.8842 - val_acc: 0.1000
# Epoch 17/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7919 - acc: 0.3111 - val_loss: 1.9043 - val_acc: 0.1000
# Epoch 18/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7921 - acc: 0.2000 - val_loss: 1.8828 - val_acc: 0.2000
# Epoch 19/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7624 - acc: 0.3556 - val_loss: 1.9242 - val_acc: 0.2333
# Epoch 20/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7310 - acc: 0.2667 - val_loss: 1.9353 - val_acc: 0.1000
# Epoch 21/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7773 - acc: 0.2667 - val_loss: 1.8732 - val_acc: 0.2667
# Epoch 22/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7377 - acc: 0.2778 - val_loss: 1.8577 - val_acc: 0.2667
# Epoch 23/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7040 - acc: 0.2444 - val_loss: 2.0485 - val_acc: 0.1333
# Epoch 24/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7953 - acc: 0.2889 - val_loss: 1.8608 - val_acc: 0.1667
# Epoch 25/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6472 - acc: 0.3111 - val_loss: 1.8701 - val_acc: 0.2000
# Epoch 26/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7361 - acc: 0.3889 - val_loss: 1.7910 - val_acc: 0.1000
# Epoch 27/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6791 - acc: 0.3111 - val_loss: 1.9370 - val_acc: 0.2667
# Epoch 28/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7977 - acc: 0.2889 - val_loss: 1.7806 - val_acc: 0.1667
# Epoch 29/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6386 - acc: 0.3111 - val_loss: 1.8845 - val_acc: 0.2000
# Epoch 30/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6807 - acc: 0.3333 - val_loss: 1.8731 - val_acc: 0.3667
# Epoch 31/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6975 - acc: 0.3556 - val_loss: 1.8194 - val_acc: 0.2000
# Epoch 32/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6954 - acc: 0.3111 - val_loss: 1.8130 - val_acc: 0.2333
# Epoch 33/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6795 - acc: 0.3222 - val_loss: 1.8503 - val_acc: 0.4000
# Epoch 34/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5636 - acc: 0.3889 - val_loss: 1.7762 - val_acc: 0.3333
# Epoch 35/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6240 - acc: 0.2889 - val_loss: 1.9353 - val_acc: 0.3667
# Epoch 36/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5497 - acc: 0.4333 - val_loss: 1.8047 - val_acc: 0.2333
# Epoch 37/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6057 - acc: 0.3000 - val_loss: 1.7748 - val_acc: 0.2667
# Epoch 38/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5479 - acc: 0.3778 - val_loss: 1.6951 - val_acc: 0.4000
# Epoch 39/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5601 - acc: 0.4111 - val_loss: 1.7171 - val_acc: 0.3667
# Epoch 40/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5227 - acc: 0.4222 - val_loss: 1.8689 - val_acc: 0.4000
# Epoch 41/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4903 - acc: 0.4222 - val_loss: 1.7420 - val_acc: 0.3667
# Epoch 42/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4943 - acc: 0.3778 - val_loss: 1.7570 - val_acc: 0.4333
# Epoch 43/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3696 - acc: 0.5222 - val_loss: 1.5731 - val_acc: 0.4333
# Epoch 44/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4783 - acc: 0.4000 - val_loss: 1.8156 - val_acc: 0.3667
# Epoch 45/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4564 - acc: 0.4222 - val_loss: 1.5500 - val_acc: 0.2667
# Epoch 46/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.4673 - acc: 0.4222 - val_loss: 1.7967 - val_acc: 0.4333
# Epoch 47/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.3474 - acc: 0.5444 - val_loss: 1.5935 - val_acc: 0.5000
# Epoch 48/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.3338 - acc: 0.5333 - val_loss: 1.4677 - val_acc: 0.4000
# Epoch 49/200
# 12/12 [==============================] - 0s 11ms/step - loss: 1.2971 - acc: 0.5111 - val_loss: 1.4887 - val_acc: 0.4000
# Epoch 50/200
# 12/12 [==============================] - 0s 12ms/step - loss: 1.2470 - acc: 0.5333 - val_loss: 1.6725 - val_acc: 0.4000
# Epoch 51/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.3101 - acc: 0.5333 - val_loss: 1.4202 - val_acc: 0.4000
# Epoch 52/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2165 - acc: 0.5000 - val_loss: 1.4101 - val_acc: 0.4000
# Epoch 53/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2808 - acc: 0.4778 - val_loss: 1.7237 - val_acc: 0.4667
# Epoch 54/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2996 - acc: 0.4778 - val_loss: 1.5541 - val_acc: 0.3667
# Epoch 55/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2134 - acc: 0.5444 - val_loss: 1.5211 - val_acc: 0.4333
# Epoch 56/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5197 - acc: 0.4333 - val_loss: 1.5604 - val_acc: 0.4667
# Epoch 57/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3279 - acc: 0.5444 - val_loss: 1.3980 - val_acc: 0.3667
# Epoch 58/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1717 - acc: 0.5667 - val_loss: 1.5378 - val_acc: 0.4000
# Epoch 59/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1567 - acc: 0.5556 - val_loss: 1.6212 - val_acc: 0.4333
# Epoch 60/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1343 - acc: 0.5667 - val_loss: 1.4752 - val_acc: 0.4333
# Epoch 61/200
# 12/12 [==============================] - 0s 11ms/step - loss: 1.1078 - acc: 0.5444 - val_loss: 1.7115 - val_acc: 0.4333
# Epoch 62/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.3821 - acc: 0.4444 - val_loss: 1.4808 - val_acc: 0.4000
# Epoch 63/200
# 12/12 [==============================] - 0s 11ms/step - loss: 1.0591 - acc: 0.6667 - val_loss: 1.4265 - val_acc: 0.5000
# Epoch 64/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0860 - acc: 0.6222 - val_loss: 1.6723 - val_acc: 0.4000
# Epoch 65/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0429 - acc: 0.6000 - val_loss: 1.4290 - val_acc: 0.4667
# Epoch 66/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2067 - acc: 0.5556 - val_loss: 1.7747 - val_acc: 0.3000
# Epoch 67/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1811 - acc: 0.5667 - val_loss: 1.3766 - val_acc: 0.4000
# Epoch 68/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1867 - acc: 0.5889 - val_loss: 1.4319 - val_acc: 0.4333
# Epoch 69/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0839 - acc: 0.5889 - val_loss: 1.5225 - val_acc: 0.4333
# Epoch 70/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9501 - acc: 0.6444 - val_loss: 1.5832 - val_acc: 0.4000
# Epoch 71/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0416 - acc: 0.6778 - val_loss: 1.5368 - val_acc: 0.3667
# Epoch 72/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9677 - acc: 0.6778 - val_loss: 1.5873 - val_acc: 0.5000
# Epoch 73/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9601 - acc: 0.6778 - val_loss: 1.3982 - val_acc: 0.4333
# Epoch 74/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9504 - acc: 0.7000 - val_loss: 1.6888 - val_acc: 0.5000
# Epoch 75/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9721 - acc: 0.6111 - val_loss: 1.6549 - val_acc: 0.4000
# Epoch 76/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0221 - acc: 0.5667 - val_loss: 1.9350 - val_acc: 0.3667
# Epoch 77/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.3303 - acc: 0.5444 - val_loss: 1.6030 - val_acc: 0.4333
# Epoch 78/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.1028 - acc: 0.5778 - val_loss: 1.4307 - val_acc: 0.3333
# Epoch 79/200
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0989 - acc: 0.6222 - val_loss: 1.5956 - val_acc: 0.4333
# Epoch 80/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9872 - acc: 0.6222 - val_loss: 1.4025 - val_acc: 0.5000
# Epoch 81/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8893 - acc: 0.7000 - val_loss: 1.6850 - val_acc: 0.4000
# Epoch 82/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.9236 - acc: 0.6667 - val_loss: 1.5583 - val_acc: 0.4000
# Epoch 83/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8592 - acc: 0.7111 - val_loss: 1.5391 - val_acc: 0.4000
# Epoch 84/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8209 - acc: 0.7111 - val_loss: 1.6985 - val_acc: 0.5000
# Epoch 85/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9425 - acc: 0.6333 - val_loss: 1.5699 - val_acc: 0.5000
# Epoch 86/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9186 - acc: 0.6778 - val_loss: 1.6649 - val_acc: 0.5000
# Epoch 87/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0371 - acc: 0.7000 - val_loss: 1.3462 - val_acc: 0.4000
# Epoch 88/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8985 - acc: 0.7556 - val_loss: 1.7148 - val_acc: 0.4667
# Epoch 89/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8844 - acc: 0.6667 - val_loss: 1.7149 - val_acc: 0.4667
# Epoch 90/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8127 - acc: 0.7111 - val_loss: 1.5871 - val_acc: 0.4000
# Epoch 91/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7847 - acc: 0.7111 - val_loss: 1.5704 - val_acc: 0.4333
# Epoch 92/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8064 - acc: 0.7333 - val_loss: 1.6266 - val_acc: 0.4000
# Epoch 93/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9103 - acc: 0.6444 - val_loss: 1.6330 - val_acc: 0.5333
# Epoch 94/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9911 - acc: 0.6556 - val_loss: 1.4352 - val_acc: 0.3667
# Epoch 95/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9220 - acc: 0.6667 - val_loss: 1.4736 - val_acc: 0.4667
# Epoch 96/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8129 - acc: 0.7556 - val_loss: 1.5878 - val_acc: 0.4333
# Epoch 97/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8113 - acc: 0.7444 - val_loss: 1.4296 - val_acc: 0.4667
# Epoch 98/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8023 - acc: 0.7444 - val_loss: 1.7052 - val_acc: 0.5000
# Epoch 99/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9002 - acc: 0.6778 - val_loss: 2.1091 - val_acc: 0.4000
# Epoch 100/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0644 - acc: 0.6556 - val_loss: 1.3516 - val_acc: 0.4667
# Epoch 101/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.3445 - acc: 0.5222 - val_loss: 1.8072 - val_acc: 0.3000
# Epoch 102/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9828 - acc: 0.6556 - val_loss: 1.3643 - val_acc: 0.5333
# Epoch 103/200
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0149 - acc: 0.6667 - val_loss: 1.3235 - val_acc: 0.4333
# Epoch 104/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8465 - acc: 0.7444 - val_loss: 1.7006 - val_acc: 0.4667
# Epoch 105/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7456 - acc: 0.8111 - val_loss: 1.3089 - val_acc: 0.5333
# Epoch 106/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7174 - acc: 0.7778 - val_loss: 1.3966 - val_acc: 0.5000
# Epoch 107/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7930 - acc: 0.6889 - val_loss: 1.4611 - val_acc: 0.5000
# Epoch 108/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8262 - acc: 0.6778 - val_loss: 1.4056 - val_acc: 0.5000
# Epoch 109/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7011 - acc: 0.8000 - val_loss: 1.6125 - val_acc: 0.4667
# Epoch 110/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7915 - acc: 0.7333 - val_loss: 1.4911 - val_acc: 0.5333
# Epoch 111/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8300 - acc: 0.7556 - val_loss: 1.5186 - val_acc: 0.4333
# Epoch 112/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7113 - acc: 0.7667 - val_loss: 1.5914 - val_acc: 0.4667
# Epoch 113/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7135 - acc: 0.8000 - val_loss: 1.7813 - val_acc: 0.4333
# Epoch 114/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7134 - acc: 0.7556 - val_loss: 1.5213 - val_acc: 0.4667
# Epoch 115/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6675 - acc: 0.7556 - val_loss: 1.7289 - val_acc: 0.4667
# Epoch 116/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7196 - acc: 0.7667 - val_loss: 1.4834 - val_acc: 0.5000
# Epoch 117/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6434 - acc: 0.7667 - val_loss: 1.5411 - val_acc: 0.4667
# Epoch 118/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7374 - acc: 0.7444 - val_loss: 1.4928 - val_acc: 0.4000
# Epoch 119/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7369 - acc: 0.7333 - val_loss: 1.6014 - val_acc: 0.5667
# Epoch 120/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7826 - acc: 0.7111 - val_loss: 1.8798 - val_acc: 0.4000
# Epoch 121/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8207 - acc: 0.7444 - val_loss: 1.5589 - val_acc: 0.5000
# Epoch 122/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6873 - acc: 0.8111 - val_loss: 1.7458 - val_acc: 0.4667
# Epoch 123/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6947 - acc: 0.7333 - val_loss: 1.5192 - val_acc: 0.4667
# Epoch 124/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7195 - acc: 0.7667 - val_loss: 1.6271 - val_acc: 0.4667
# Epoch 125/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6828 - acc: 0.7889 - val_loss: 1.6731 - val_acc: 0.5000
# Epoch 126/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6263 - acc: 0.8111 - val_loss: 1.5486 - val_acc: 0.4667
# Epoch 127/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6867 - acc: 0.7667 - val_loss: 1.5502 - val_acc: 0.4667
# Epoch 128/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6422 - acc: 0.7778 - val_loss: 1.6634 - val_acc: 0.4333
# Epoch 129/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6771 - acc: 0.7667 - val_loss: 1.6063 - val_acc: 0.4667
# Epoch 130/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7347 - acc: 0.7889 - val_loss: 1.9281 - val_acc: 0.5000
# Epoch 131/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7226 - acc: 0.7778 - val_loss: 1.4730 - val_acc: 0.5000
# Epoch 132/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7893 - acc: 0.7556 - val_loss: 1.5637 - val_acc: 0.5667
# Epoch 133/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7897 - acc: 0.7111 - val_loss: 1.5854 - val_acc: 0.4333
# Epoch 134/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7184 - acc: 0.7667 - val_loss: 1.5040 - val_acc: 0.5667
# Epoch 135/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7031 - acc: 0.7556 - val_loss: 1.5652 - val_acc: 0.5667
# Epoch 136/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6991 - acc: 0.7556 - val_loss: 1.6496 - val_acc: 0.4333
# Epoch 137/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6401 - acc: 0.8000 - val_loss: 1.4826 - val_acc: 0.5000
# Epoch 138/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6857 - acc: 0.7778 - val_loss: 1.7492 - val_acc: 0.4667
# Epoch 139/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6312 - acc: 0.8222 - val_loss: 1.5561 - val_acc: 0.4667
# Epoch 140/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6664 - acc: 0.8000 - val_loss: 1.4872 - val_acc: 0.5000
# Epoch 141/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6877 - acc: 0.7889 - val_loss: 1.5510 - val_acc: 0.4667
# Epoch 142/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6809 - acc: 0.7667 - val_loss: 1.8277 - val_acc: 0.4333
# Epoch 143/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7125 - acc: 0.7778 - val_loss: 1.5617 - val_acc: 0.5667
# Epoch 144/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7461 - acc: 0.7889 - val_loss: 1.6823 - val_acc: 0.4667
# Epoch 145/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6287 - acc: 0.8000 - val_loss: 1.5544 - val_acc: 0.5667
# Epoch 146/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6114 - acc: 0.8111 - val_loss: 1.6208 - val_acc: 0.4667
# Epoch 147/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6662 - acc: 0.8111 - val_loss: 1.5793 - val_acc: 0.5000
# Epoch 148/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6543 - acc: 0.8556 - val_loss: 1.4622 - val_acc: 0.4333
# Epoch 149/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6346 - acc: 0.7778 - val_loss: 1.6471 - val_acc: 0.4333
# Epoch 150/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6752 - acc: 0.7778 - val_loss: 1.5941 - val_acc: 0.5000
# Epoch 151/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6186 - acc: 0.8111 - val_loss: 1.5583 - val_acc: 0.4667
# Epoch 152/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6137 - acc: 0.8333 - val_loss: 1.5925 - val_acc: 0.5333
# Epoch 153/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6506 - acc: 0.8222 - val_loss: 1.7026 - val_acc: 0.5333
# Epoch 154/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5847 - acc: 0.8333 - val_loss: 1.7995 - val_acc: 0.5000
# Epoch 155/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6045 - acc: 0.8222 - val_loss: 1.5928 - val_acc: 0.5333

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss for EEG LSTM')
plt.ylabel('Loss value')
plt.xlabel('# epoch')
plt.legend(loc="upper left")
plt.show()
