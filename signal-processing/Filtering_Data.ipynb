# %% [markdown]
# <h1> Imports

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt 
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFdr
from scipy.signal import butter, lfilter, filtfilt, freqz
from scipy import signal
import pywt

# %% [markdown]
# <h1> Fitlering Functions

# %%
def apply_butterband_filter(input_df):
    df = input_df.copy()
    for col in df.columns:
        df[col] = filter_df_col(df, col)
        
    return df

def filter_df_col(df, col):
    fs = 512.0
    lowcut = 12.0
    highcut = 25.0
    
    vals = df[col].values
    return butter_bandpass_filter(vals, lowcut, highcut, fs)

def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=3):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    data = data * 50    # amplify data
    y = filtfilt(b, a, data)
    return y

# %%
def wavelet_dwt(df):
    return pywt.dwt2(df.values, 'db4')

def pca_and_inverse(df):
    pca = PCA(0.95).fit(df)
    components = pca.transform(df)
    return pca.inverse_transform(components)
    
def pca_feature_selection(df):
    pca = PCA(1).fit(df)
    return pca.transform(df)

# %%
record_export_folder = 'EEG_Recordings'
keep_cols = ['EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8'] # ['Timestamp', 'EEG.Counter', 'EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8']

def load_df(file_name):
    file_path = os.path.join(record_export_folder, file_name)
    return pd.read_csv(file_path, skiprows=0, header=1)

def trim_cols(df):
    return df[keep_cols]

def filter_data(df):
#     df = apply_butterband_filter(df)
    return wavelet_dwt(df)

# %%
df = trim_cols(load_df('sultan_checkerboard_{}.csv'.format(1)))
approx, decomp = filter_data(df)
decomp = np.asarray(decomp)

# %%
print(approx.shape)
print(decomp.shape)
# Out:
# (1939, 5)
# (3, 1939, 5)

# %% [markdown]
# <h1> Data from 4 Sensors

# %%
subplot = 0
fig, axs = plt.subplots(4)
for col in df.columns:
    axs[subplot].plot(df[col].values)
    subplot += 1

# %% [markdown]
# <h1> Wavlet Decomposition

# %%
bands = approx.shape[1]
subplot = 0
axis = 0
fig, axs = plt.subplots(bands, 3)
for axis in [0,1,2]:
    for col in range(decomp.shape[2]):
        axs[subplot, axis].plot(dataset[axis,:,col])
        subplot += 1
    subplot = 0

# %%
bands = approx.shape[1]
subplot = 0
axis = 0
fig, axs = plt.subplots(bands, 2)
for dataset in [approx, decomp]:
    for col in range(bands):
        axs[subplot, axis].plot(dataset[:,col])
        subplot += 1
    subplot = 0
    axis += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-160ad4bf3ee0> in <module>
#       5 for dataset in [approx, decomp]:
#       6     for col in range(bands):
# ----> 7         axs[subplot, axis].plot(dataset[:,col])
#       8         subplot += 1
#       9     subplot = 0
#
# TypeError: tuple indices must be integers or slices, not tuple

# %% [markdown]
# <h1> PCA Seperating Approx and Discrete

# %%
bands = approx.shape[1]
subplot = 0
axis = 0
pca_approx = pca_and_inverse(approx) 
pca_decomp = pca_and_inverse(decomp)
fig, axs = plt.subplots(bands, 2)
for dataset in [pca_approx, pca_decomp]:
    for col in range(bands):
        axs[subplot, axis].plot(dataset[:,col])
        subplot += 1
    subplot = 0
    axis += 1

# %% [markdown]
# <h1> PCA

# %%
subplot = 0
axis = 0
full = np.concatenate((approx, decomp), axis=1)
pca_full = pca_and_inverse(full)
bands = pca_full.shape[1]

# %%
fig, axs = plt.subplots(int(bands / 2), 2)
for col in range(bands):
    axs[subplot, axis].plot(pca_full[:,col])
    subplot += 1
    if subplot == int(bands / 2):
        subplot = 0
        axis += 1

# %% [markdown]
# <h1> Training Data

# %%
seconds_to_check = 1
interval_range = int(128 * seconds_to_check)
data_points = int(30 / seconds_to_check)

def split_to_training_data(df):
    total_data = []
    for interval_start in range(0, interval_range * data_points, interval_range):
        temp_data = []
        for col in range(0, df.shape[1]):
            temp_data.append(df[interval_start:interval_start + interval_range, col])
        
        total_data.append(temp_data)
        
    return np.asarray(total_data)

def create_target_data(data, target):
    return np.asarray([target] * data.shape[0])

# %%
from tensorflow.keras.utils import to_categorical

# %%
targets = range(1, 9)
total_train_x = []
total_train_y = []
for target in targets:
    df = trim_cols(load_df('sultan_checkerboard_{}.csv'.format(target)))
    approx, decomp = filter_data(df)
    pca_approx = pca_and_inverse(approx) 
    pca_decomp = pca_and_inverse(decomp)
    filtered_df = np.concatenate((pca_approx, pca_decomp), axis=1)
    filtered_df = pca_approx
    train_x = split_to_training_data(filtered_df)
    train_y = create_target_data(train_x, target - 1)
    if target == 1:
        total_train_x = train_x
        total_train_y = train_y
    else:
        total_train_x = np.concatenate((total_train_x, train_x))
        total_train_y = np.concatenate((total_train_y, train_y))

# %%
# targets = range(1, 9)
# total_train_x = []
# total_train_y = []
# for target in targets:
#     df = trim_cols(load_df('sultan_checkerboard_{}.csv'.format(target)))
#     filtered_df = filter_data(df)
#     train_x = split_to_training_data(filtered_df)
#     train_y = create_target_data(train_x, target - 1)
#     if target == 1:
#         total_train_x = train_x
#         total_train_y = train_y
#     else:
#         total_train_x = np.concatenate((total_train_x, train_x))
#         total_train_y = np.concatenate((total_train_y, train_y))

# %%
# total_train_y = to_categorical(total_train_y, num_classes=8)

# %%
total_train_x.shape
# Out:
# (240, 5, 128)

# %%
# total_train_x = total_train_x.reshape(total_train_x.shape[0], -1)

# %%
train_x, validation_x, train_y, validation_y = train_test_split(total_train_x, total_train_y, test_size = 0.2)

# %%
from sklearn.svm import LinearSVC, SVC

# %%
# svc = LinearSVC()
# svc.fit(train_x, train_y)

# %%
# svc.score(validation_x, validation_y)

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, GRU, BatchNormalization, LayerNormalization, ActivityRegularization
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping

# %%
def create_model():
    model = Sequential()
    model.add(LSTM(16, input_shape=(train_x.shape[1:]), return_sequences=True))
    model.add(Dropout(0.25))
    model.add(ActivityRegularization(l2=0.01))
    model.add(BatchNormalization())

    model.add(LSTM(16, input_shape=(train_x.shape[1:]), return_sequences=False))
    model.add(Dropout(0.25))
    model.add(ActivityRegularization(l2=0.01))
    model.add(BatchNormalization())

    model.add(Dense(16))

    model.add(Dense(8, activation="softmax"))
    
    return model

# %%
EPOCHS = 100
BATCH_SIZE = 16
NAME= "models\BEST"

# %%
model = create_model()
    
opt = tf.keras.optimizers.Adam()

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt, metrics=['acc'])

callbacks = [
    #TensorBoard(f"logs\{RATIO_TO_PREDICT}-VOLUME-{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"),
#     ReduceLROnPlateau(patience=10, factor=0.1),
#     EarlyStopping(patience=12),
#     ModelCheckpoint(filepath=NAME, monitor='val_loss', verbose=2, save_weights_only=True, save_best_only=True, mode='min')
]
    
history = model.fit(train_x,
                    train_y,
                    batch_size= BATCH_SIZE,
                    epochs = EPOCHS,
                    validation_data=(validation_x, validation_y), 
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 113ms/step - loss: 2.6198 - acc: 0.1510 - val_loss: 2.2967 - val_acc: 0.1458
# Epoch 2/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6339 - acc: 0.0938 - val_loss: 2.2895 - val_acc: 0.1458
# Epoch 3/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6645 - acc: 0.0938 - val_loss: 2.2892 - val_acc: 0.1458
# Epoch 4/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5736 - acc: 0.1146 - val_loss: 2.2878 - val_acc: 0.1458
# Epoch 5/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4317 - acc: 0.1771 - val_loss: 2.2874 - val_acc: 0.1458
# Epoch 6/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4759 - acc: 0.1302 - val_loss: 2.2882 - val_acc: 0.1458
# Epoch 7/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5100 - acc: 0.1302 - val_loss: 2.2894 - val_acc: 0.1042
# Epoch 8/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4324 - acc: 0.1510 - val_loss: 2.2856 - val_acc: 0.1458
# Epoch 9/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4248 - acc: 0.1198 - val_loss: 2.2845 - val_acc: 0.1042
# Epoch 10/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4462 - acc: 0.1354 - val_loss: 2.2841 - val_acc: 0.1042
# Epoch 11/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4971 - acc: 0.1146 - val_loss: 2.2837 - val_acc: 0.1042
# Epoch 12/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3822 - acc: 0.1302 - val_loss: 2.2844 - val_acc: 0.0833
# Epoch 13/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4407 - acc: 0.0990 - val_loss: 2.2837 - val_acc: 0.0833
# Epoch 14/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4304 - acc: 0.1354 - val_loss: 2.2851 - val_acc: 0.0833
# Epoch 15/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4473 - acc: 0.1146 - val_loss: 2.2864 - val_acc: 0.0833
# Epoch 16/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4014 - acc: 0.1250 - val_loss: 2.2860 - val_acc: 0.0833
# Epoch 17/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3647 - acc: 0.1406 - val_loss: 2.2858 - val_acc: 0.0833
# Epoch 18/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4649 - acc: 0.0938 - val_loss: 2.2869 - val_acc: 0.0833
# Epoch 19/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3885 - acc: 0.1250 - val_loss: 2.2870 - val_acc: 0.0833
# Epoch 20/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4410 - acc: 0.0990 - val_loss: 2.2865 - val_acc: 0.0833
# Epoch 21/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3722 - acc: 0.1458 - val_loss: 2.2860 - val_acc: 0.0833
# Epoch 22/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4052 - acc: 0.1198 - val_loss: 2.2868 - val_acc: 0.0833
# Epoch 23/100
# 12/12 [==============================] - ETA: 0s - loss: 2.4043 - acc: 0.136 - 0s 7ms/step - loss: 2.4047 - acc: 0.1406 - val_loss: 2.2864 - val_acc: 0.0833
# Epoch 24/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3838 - acc: 0.1615 - val_loss: 2.2866 - val_acc: 0.0833
# Epoch 25/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4002 - acc: 0.1250 - val_loss: 2.2878 - val_acc: 0.0833
# Epoch 26/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3844 - acc: 0.1458 - val_loss: 2.2898 - val_acc: 0.0833
# Epoch 27/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3430 - acc: 0.1406 - val_loss: 2.2899 - val_acc: 0.0833
# Epoch 28/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4087 - acc: 0.1198 - val_loss: 2.2879 - val_acc: 0.0833
# Epoch 29/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3852 - acc: 0.1562 - val_loss: 2.2878 - val_acc: 0.0833
# Epoch 30/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3354 - acc: 0.1354 - val_loss: 2.2890 - val_acc: 0.0833
# Epoch 31/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4130 - acc: 0.1302 - val_loss: 2.2902 - val_acc: 0.0833
# Epoch 32/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3998 - acc: 0.1250 - val_loss: 2.2894 - val_acc: 0.0833
# Epoch 33/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3683 - acc: 0.1250 - val_loss: 2.2899 - val_acc: 0.0833
# Epoch 34/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3662 - acc: 0.1458 - val_loss: 2.2896 - val_acc: 0.0833
# Epoch 35/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3499 - acc: 0.1562 - val_loss: 2.2892 - val_acc: 0.0833
# Epoch 36/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3862 - acc: 0.0990 - val_loss: 2.2895 - val_acc: 0.0833
# Epoch 37/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4078 - acc: 0.1146 - val_loss: 2.2893 - val_acc: 0.0833
# Epoch 38/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4001 - acc: 0.1354 - val_loss: 2.2884 - val_acc: 0.0833
# Epoch 39/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3540 - acc: 0.1458 - val_loss: 2.2872 - val_acc: 0.0833
# Epoch 40/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3619 - acc: 0.1094 - val_loss: 2.2877 - val_acc: 0.0833
# Epoch 41/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3626 - acc: 0.0938 - val_loss: 2.2878 - val_acc: 0.0833
# Epoch 42/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3616 - acc: 0.1406 - val_loss: 2.2895 - val_acc: 0.0833
# Epoch 43/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3640 - acc: 0.0885 - val_loss: 2.2893 - val_acc: 0.0833
# Epoch 44/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3616 - acc: 0.1250 - val_loss: 2.2902 - val_acc: 0.0833
# Epoch 45/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3443 - acc: 0.1250 - val_loss: 2.2894 - val_acc: 0.0833
# Epoch 46/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3963 - acc: 0.1042 - val_loss: 2.2884 - val_acc: 0.0833
# Epoch 47/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3553 - acc: 0.0833 - val_loss: 2.2896 - val_acc: 0.0833
# Epoch 48/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3606 - acc: 0.1094 - val_loss: 2.2887 - val_acc: 0.0833
# Epoch 49/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3922 - acc: 0.1302 - val_loss: 2.2894 - val_acc: 0.0833
# Epoch 50/100
# 12/12 [==============================] - 0s 9ms/step - loss: 2.3465 - acc: 0.1615 - val_loss: 2.2904 - val_acc: 0.0833
# Epoch 51/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3655 - acc: 0.1458 - val_loss: 2.2911 - val_acc: 0.0833
# Epoch 52/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3799 - acc: 0.1146 - val_loss: 2.2906 - val_acc: 0.0833
# Epoch 53/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3648 - acc: 0.1250 - val_loss: 2.2907 - val_acc: 0.0833
# Epoch 54/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3825 - acc: 0.1510 - val_loss: 2.2902 - val_acc: 0.0833
# Epoch 55/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3682 - acc: 0.1094 - val_loss: 2.2905 - val_acc: 0.0833
# Epoch 56/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3836 - acc: 0.0990 - val_loss: 2.2906 - val_acc: 0.0833
# Epoch 57/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3692 - acc: 0.0833 - val_loss: 2.2907 - val_acc: 0.0833
# Epoch 58/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3541 - acc: 0.1406 - val_loss: 2.2908 - val_acc: 0.0833
# Epoch 59/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3583 - acc: 0.1146 - val_loss: 2.2917 - val_acc: 0.0833
# Epoch 60/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3881 - acc: 0.0781 - val_loss: 2.2925 - val_acc: 0.0833
# Epoch 61/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3514 - acc: 0.1615 - val_loss: 2.2931 - val_acc: 0.0833
# Epoch 62/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3638 - acc: 0.0938 - val_loss: 2.2923 - val_acc: 0.0833
# Epoch 63/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3378 - acc: 0.1198 - val_loss: 2.2921 - val_acc: 0.0833
# Epoch 64/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3444 - acc: 0.1719 - val_loss: 2.2925 - val_acc: 0.0833
# Epoch 65/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3544 - acc: 0.1302 - val_loss: 2.2936 - val_acc: 0.0833
# Epoch 66/100
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3629 - acc: 0.1354 - val_loss: 2.2929 - val_acc: 0.0833
# Epoch 67/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3791 - acc: 0.1094 - val_loss: 2.2924 - val_acc: 0.0833
# Epoch 68/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3586 - acc: 0.1250 - val_loss: 2.2924 - val_acc: 0.0833
# Epoch 69/100
# 12/12 [==============================] - 0s 10ms/step - loss: 2.3707 - acc: 0.1354 - val_loss: 2.2915 - val_acc: 0.0833
# Epoch 70/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3409 - acc: 0.1302 - val_loss: 2.2924 - val_acc: 0.0833
# Epoch 71/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3537 - acc: 0.1458 - val_loss: 2.2920 - val_acc: 0.0833
# Epoch 72/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3509 - acc: 0.1198 - val_loss: 2.2930 - val_acc: 0.0833
# Epoch 73/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3722 - acc: 0.0938 - val_loss: 2.2925 - val_acc: 0.0833
# Epoch 74/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3559 - acc: 0.0990 - val_loss: 2.2928 - val_acc: 0.0833
# Epoch 75/100
# 12/12 [==============================] - 0s 9ms/step - loss: 2.3365 - acc: 0.1042 - val_loss: 2.2924 - val_acc: 0.0833
# Epoch 76/100
# 12/12 [==============================] - 0s 10ms/step - loss: 2.3572 - acc: 0.1198 - val_loss: 2.2917 - val_acc: 0.0833
# Epoch 77/100
# 12/12 [==============================] - 0s 9ms/step - loss: 2.3271 - acc: 0.1719 - val_loss: 2.2911 - val_acc: 0.0833
# Epoch 78/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3710 - acc: 0.1146 - val_loss: 2.2901 - val_acc: 0.0833
# Epoch 79/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3455 - acc: 0.1354 - val_loss: 2.2908 - val_acc: 0.0833
# Epoch 80/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3553 - acc: 0.1250 - val_loss: 2.2916 - val_acc: 0.0833
# Epoch 81/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3381 - acc: 0.1354 - val_loss: 2.2919 - val_acc: 0.0833
# Epoch 82/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3566 - acc: 0.1250 - val_loss: 2.2915 - val_acc: 0.0833
# Epoch 83/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3796 - acc: 0.0938 - val_loss: 2.2914 - val_acc: 0.0833
# Epoch 84/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3590 - acc: 0.1042 - val_loss: 2.2916 - val_acc: 0.0833
# Epoch 85/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3377 - acc: 0.1510 - val_loss: 2.2909 - val_acc: 0.0833
# Epoch 86/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3519 - acc: 0.1198 - val_loss: 2.2908 - val_acc: 0.0833
# Epoch 87/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3653 - acc: 0.0990 - val_loss: 2.2901 - val_acc: 0.0833
# Epoch 88/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3479 - acc: 0.1302 - val_loss: 2.2899 - val_acc: 0.0833
# Epoch 89/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3422 - acc: 0.1302 - val_loss: 2.2906 - val_acc: 0.0833
# Epoch 90/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3564 - acc: 0.1354 - val_loss: 2.2910 - val_acc: 0.0833
# Epoch 91/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3420 - acc: 0.1198 - val_loss: 2.2913 - val_acc: 0.0833
# Epoch 92/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3441 - acc: 0.1458 - val_loss: 2.2920 - val_acc: 0.0833
# Epoch 93/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3572 - acc: 0.1510 - val_loss: 2.2928 - val_acc: 0.0833
# Epoch 94/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3442 - acc: 0.1406 - val_loss: 2.2929 - val_acc: 0.0833
# Epoch 95/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3337 - acc: 0.1458 - val_loss: 2.2935 - val_acc: 0.0833
# Epoch 96/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3295 - acc: 0.1406 - val_loss: 2.2928 - val_acc: 0.0833
# Epoch 97/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3444 - acc: 0.1406 - val_loss: 2.2931 - val_acc: 0.0833
# Epoch 98/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3332 - acc: 0.1198 - val_loss: 2.2915 - val_acc: 0.0833
# Epoch 99/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3242 - acc: 0.1615 - val_loss: 2.2915 - val_acc: 0.0833
# Epoch 100/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3517 - acc: 0.1354 - val_loss: 2.2921 - val_acc: 0.0833
